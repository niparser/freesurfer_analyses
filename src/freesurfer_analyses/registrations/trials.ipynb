# %%
from dmriprep_analyses.parcellations.parcellations import NativeParcellation
from dmriprep_analyses.tensors.tensor_estimation_mrtrix import TensorEstimation

tensors = NativeParcellation("/media/groot/Yalla/ConnectomePlasticity/MRI/derivatives/dmriprep")
tensors.tensor_estimation = TensorEstimation(tensors.data_grabber.base_dir)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1341581/4057313144.py in <module>
#       1 from dmriprep_analyses.parcellations.parcellations import NativeParcellation
#       2 from dmriprep_analyses.tensors.tensor_estimation_mrtrix import TensorEstimation
# ----> 3 tensors = NativeParcellation("/media/groot/Yalla/ConnectomePlasticity/MRI/derivatives/dmriprep")
#       4 tensors.tensor_estimation = TensorEstimation(tensors.data_grabber.base_dir)
#
# ~/Projects/PhD/connectome_project/dmriprep_analyses/src/dmriprep_analyses/parcellations/parcellations.py in __init__(self, base_dir, participant_labels)
#      26     ) -> None:
#      27         super().__init__(base_dir, participant_labels)
# ---> 28         self.registration_manager = NativeRegistration(
#      29             base_dir, participant_labels
#      30         )
#
# ...

# %%
data = tensors.parcellate_single_tensor("brainnetome", "diffusion_tensor", "1039", force=True)
# Out:
# dwi2tensor: [100%] uncompressing image "/media/groot/Yalla/ConnectomePlasticity/MRI/derivatives/dmriprep/sub-1039/ses-202111221129/dwi/sub-1039_ses-202111221129_dir-FWD_space-T1w_desc-preproc_dwi.nii.gz"[0K
# dwi2tensor: [100%] computing tensors[0K
# tensor2metric: [100%] computing metrics[0K
# tensor2metric: [100%] compressing image "/media/groot/Yalla/ConnectomePlasticity/MRI/derivatives/dmriprep/sub-1039/ses-202111221129/dwi/sub-1039_ses-202111221129_acq-dt_dir-FWD_space-T1w_res-dwi_desc-eval_dwiref.nii.gz"[0K
# tensor2metric: [100%] compressing image "/media/groot/Yalla/ConnectomePlasticity/MRI/derivatives/dmriprep/sub-1039/ses-202111221129/dwi/sub-1039_ses-202111221129_acq-dt_dir-FWD_space-T1w_res-dwi_desc-evec_dwiref.nii.gz"[0K
# tensor2metric: [100%] compressing image "/media/groot/Yalla/ConnectomePlasticity/MRI/derivatives/dmriprep/sub-1039/ses-202111221129/dwi/sub-1039_ses-202111221129_acq-dt_dir-FWD_space-T1w_res-dwi_desc-cs_dwiref.nii.gz"[0K
# ...

# %%
for parcellation_type in ["whole_brain", "gm_cropped"]:
    data = tensors.parcellate_dataset("brainnetome", parcellation_type, force=False)
# Out:
#   0%|          | 0/27 [00:49<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/Projects/PhD/venv/lib/python3.9/site-packages/nibabel/loadsave.py in load(filename, **kwargs)
#      41     try:
# ---> 42         stat_result = os.stat(filename)
#      43     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/media/groot/Yalla/ConnectomePlasticity/MRI/derivatives/dmriprep/sub-1020/ses-202111280841/dwi/sub-1020_ses-202111280841_acq-dk_dir-FWD_space-T1w_res-dwi_desc-mk_dwiref.nii.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_717637/882698326.py in <module>
#       1 for parcellation_type in ["whole_brain","gm_cropped"]:
# ----> 2     data = tensors.parcellate_dataset("brainnetome",parcellation_type,force=False)
# ...
